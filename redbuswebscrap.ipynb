# %%
import time
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
primekey=3136
# %pip install pymysql
import pymysql
mydb = pymysql.connect(
    host="localhost",
    user="root",
    password="Malar@1976#",
    database='sri'
)
mycursor = mydb.cursor()
mycursor.execute("CREATE TABLE redbusfinal (id INT, state VARCHAR(30), route VARCHAR(30),route_link VARCHAR(60),busname VARCHAR(60),bustype VARCHAR(60),depart_time VARCHAR(30),duration VARCHAR(10),reach_time VARCHAR(30),star_rating FLOAT(2,1),price INT,seat VARCHAR(60))")
time.sleep(1)

states= ['https://www.redbus.in/online-booking/kaac-transport','https://www.redbus.in/online-booking/west-bengal-transport-corporation?utm_source=rtchometile','https://www.redbus.in/online-booking/jksrtc','https://www.redbus.in/online-booking/ktcl/?utm_source=rtchometile','https://www.redbus.in/online-booking/bihar-state-road-transport-corporation-bsrtc/?utm_source=rtchometile','https://www.redbus.in/online-booking/north-bengal-state-transport-corporation','https://www.redbus.in/online-booking/pepsu/?utm_source=rtchometile','https://www.redbus.in/online-booking/chandigarh-transport-undertaking-ctu','https://www.redbus.in/online-booking/astc/?utm_source=rtchometile','https://www.redbus.in/online-booking/hrtc/?utm_source=rtchometile']
statenames=["kaac","westbengal","jksrctc","ktcl","bihar","north bengal","pepsu","chandighar","astc","hrtc"]
statebuses={} #state to routes holder
state_routes={"kaac":[],"westbengal":[],"jksrctc":[],"ktcl":[],"bihar":[],"north bengal":[],"pepsu":[],"chandighar":[],"astc":[],"hrtc":[]}


for state in states:
    buses={} #route to buses holder
    
    driver = webdriver.Chrome()
    driver.get(state);
    time.sleep(1)

    body = driver.find_element(By.TAG_NAME,'body') #bodypage of districts
    body.send_keys(Keys.PAGE_DOWN)
    body.send_keys(Keys.PAGE_DOWN)
    body.send_keys(Keys.PAGE_DOWN)
    time.sleep(1)

    routes=driver.find_elements(By.CSS_SELECTOR,"a[class='route']") #fetching route details
    route1=list(k.text for k in routes)
    length=(len(route1))
    var=-1

    a=0
    b=0
    while a<=length:
        driver = webdriver.Chrome()
        driver.get(state);
        time.sleep(1)

        body = driver.find_element(By.TAG_NAME,'body') #bodypage of districts
        body.send_keys(Keys.PAGE_DOWN)
        time.sleep(1)

        routes=driver.find_elements(By.CSS_SELECTOR,"a[class='route']") #fetching route details
        route1=list(k.text for k in routes)
        length=(len(route1))
        oldlength=length
        


        links = [link.get_attribute('href') for link in routes]
        
        if b >= length:
            #driver.back()
            #driver.back() #to move to previous window

            body.send_keys(Keys.PAGE_DOWN)
            body.send_keys(Keys.PAGE_DOWN)

            time.sleep(2)
            body = driver.find_element(By.TAG_NAME,'body')
            nextbutton=body.find_elements(By.XPATH,"//div[@ class='DC_117_pageTabs ']")
            if b%length==0:
                var=var+1
            
            try:
                n=nextbutton[var]
                n.click() #click nexttab
            except:
                break
            body1 = driver.find_element(By.TAG_NAME,'body')
            body1.send_keys(Keys.PAGE_UP)
            body1.send_keys(Keys.PAGE_UP)
            body1.send_keys(Keys.PAGE_UP)
            routes=driver.find_elements(By.CSS_SELECTOR,"a[class='route']") #fetching route details
            route1=list(k.text for k in routes)
            body1.send_keys(Keys.PAGE_DOWN)
            time.sleep(1)
            a=b-(oldlength*(var+1))
            length=(len(route1))

        if a>3 and a<length:
            body.send_keys(Keys.PAGE_DOWN)
            time.sleep(1)
        if a>7 and a<length:
            body.send_keys(Keys.PAGE_DOWN)
            time.sleep(1)
        
        time.sleep(1)

        #print("a:",a)
        #print("b:",b)
        #print("links:",links)
        
        try:
            print("route:",route1[a])
            A1=links[a]
            J=routes[a] #bodypage of districts
            J.click()
            time.sleep(3)
            body1 = driver.find_element(By.TAG_NAME,'body') #bodypage of buses of routes
            nextar=body1.find_element(By.CSS_SELECTOR,"i[class='icon icon-right']")
            nextar.click()  #nextdaybutton
            time.sleep(3) #bodypage of districts
            down=body1.find_elements(By.CSS_SELECTOR,"div[ class='button']") #red down buton
        except:
            break

        
        

        
    
        if len(down)!=0:
            for o in down[::-1]:
                try:
                     o.click()
                except:
                    print("No button")
                    
                time.sleep(1)

        busnames=body1.find_elements(By.XPATH,"div [class='travels lh-24 f-bold d-color']")
        
        for k in range(5):
            body1.send_keys(Keys.PAGE_DOWN)
            time.sleep(1)
        busnamesc=body1.find_elements(By.XPATH,"//div[@ class='travels lh-24 f-bold d-color']")     
        while True:
            if len(busnames)==len(busnamesc):
                break
            else:
                busnames=body1.find_elements(By.XPATH,"//div[@ class='travels lh-24 f-bold d-color']")
                
                for ka in range(5):
                    body1.send_keys(Keys.PAGE_DOWN)
                
                time.sleep(2)
                busnamesc=body1.find_elements(By.XPATH,"//div [@class='travels lh-24 f-bold d-color']")
        
        #time.sleep(2)
        
        try:
            bustypec=body1.find_elements(By.XPATH,"//div[@ class='bus-type f-12 m-top-16 l-color evBus']")
            deptimec=body1.find_elements(By.XPATH,"//div[@ class='dp-time f-19 d-color f-bold']")
            durationc=body1.find_elements(By.XPATH,"//div[@ class='dur l-color lh-24']")
            arrivalc=body1.find_elements(By.XPATH,"//div[@ class='bp-time f-19 d-color disp-Inline']")
            pricec=body1.find_elements(By.XPATH,"//div[@ class='fare d-block']")
            seatavc=body1.find_elements(By.XPATH,"//div[@ class='column-eight w-15 fl']")
            starc=body1.find_elements(By.XPATH,"//div[@ class='rating-sec lh-24']")
            
            time.sleep(3)
            
            busnames1=list(q1.text for q1 in busnamesc) #list of busnames for this a route
            bustypec1=list(q2.text for q2 in bustypec) #list of bustypes of buses for this a route
            deptimec1=list(q3.text for q3 in deptimec) #list of durationtime of buses for this a route
            durationc1=list(q4.text for q4 in durationc)
            arrivalc1= list(q5.text for q5 in arrivalc)
            pricec1 = list(q6.text for q6 in pricec)
            pricec2 =[]
            import re
            for q10 in pricec1:
                input_string = q10
                output_string = re.sub(r'[^0-9]', '', input_string)
                pricec2.append(output_string)
            seatavc1 = list(q7.text for q7 in seatavc)
            starc1  = list(q8.text for q8 in starc)
            starc2=[]
            for q9 in starc1:
                q9=float(q9)
                starc2.append(q9)
            
            A=route1[a]
            buses[A]=busnames1
            statenumber=states.index(state)
            D=statenames[statenumber]
            now=state_routes[D]
            now.append(A)
            
            time.sleep(2)
            for i in range(0,len(starc1)):
                primekey=primekey+1
                B=busnames1[i]
                C=bustypec1[i]
                dep=deptimec1[i]
                dur=durationc1[i]
                arr=arrivalc1[i]
                starrate=starc2[i]
                pr=pricec2[i]
                seat=seatavc1[i]

                query = "INSERT INTO redbusfinal (id,state,route,route_link,busname,bustype,depart_time,duration,reach_time,star_rating,price,seat) VALUES (%s, %s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)"
                data = (primekey,D,A,A1,B,C,dep,dur,arr,starrate,pr,seat)
                mycursor.execute(query,data)
                time.sleep(2)
                
        except:
            print("no")
            print("busname",len(busnames1),busnames1)
            print("bustype to this",len(bustypec1),bustypec1)
            print("busdepttime to this",len(deptimec1),deptimec1)
            print("busduration",len(durationc1),durationc1)
            print("busarrival",len(arrivalc1),arrivalc1)
            print("busprice",len(pricec1),pricec1)
            print("busprice",len(pricec2),pricec2)
            print("busseat",len(seatavc1),seatavc1)
            print("busstar",len(starc1),starc1)
            print("busstar",len(starc2),starc2)
        mydb.commit()
        time.sleep(2)
        a=a+1
        b=b+1
        print(state_routes)
    statebuses[state]=buses #linking state to (busroute to buses)

# %%
print(state_routes)
